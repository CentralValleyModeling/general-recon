# %%
import yaml

from utils.tools import (make_summary_df, month_map, load_data_mult, 
                   make_ressum_df, month_list, convert_cm_nums,
                   wyt_list, convert_wyt_nums, cfs_taf)

# %%
with open('constants/vars.yaml', 'r') as file:
    var_dict = yaml.safe_load(file)

# %%
var_dict2={}
for key in var_dict:
    for subkey in list(var_dict[key]):
        if subkey != 'alias':
            del var_dict[key][subkey]
    var_dict2[key]=var_dict[key]['alias']

var_dict2
# Out:
# {'BD_EC_MONTH': 'Salinity - BD EC',
#  'CI_EC_MONTH': 'Salinity - CI EC',
#  'CO_AVAILABLE_DV': 'Delivery - SWP CO available',
#  'CO_EC_MONTH': 'Salinity - CO EC',
#  'CO_EST_DV': 'Delivery - SWP CO est',
#  'CO_FINAL_DV': 'Delivery - SWP CO final',
#  'CT_VERONA': 'Upstream Flows - Verona Closure Term',
#  'CVPRuleCv': 'Storage - SL CVP Rule curve',
#  'CVPTOTALDEL': 'Delivery - CVP Delivery SOD',
#  'C_AMR004': 'Upstream Flows - H-Street',
#  'C_CAA003': 'Total Banks Exports',
#  'C_CAA003_CVC': 'Other - Banks Export Cross Valley Pumping',
#  'C_CAA003_CVP': 'Delta - Banks CVP Exports',
#  'C_CAA003_CVPDED': 'Other - Banks Export CVP Dedicated',
#  'C_CAA003_CVPWHL': 'Other - Banks Export JPOD',
#  'C_CAA003_EXP1': 'Other - Banks Export State Share',
#  'C_CAA003_EXP2': 'Other - Banks Export Fed Share',
#  'C_CAA003_IF': 'Other - Banks PP North Delta',
#  'C_CAA003_SWP': 'Delta - Banks SWP Exports',
#  'C_CAA003_SWP_TD': 'Other - Banks PP SWP Through Delta',
#  'C_CAA003_TD': 'Other - Banks PP Through Delta',
#  'C_CAA003_WTS': 'Other - Banks Export WTS',
#  'C_CAA005': 'C_CAA005',
#  'C_CAA006': 'C_CAA006',
#  'C_CAA009': 'C_CAA009',
#  'C_CAA012': 'C_CAA012',
#  'C_CAA024': 'C_CAA024',
#  'C_CAA046': 'C_CAA046',
#  'C_CAA051': 'C_CAA051',
#  'C_CAA066': 'C_CAA066',
#  'C_CAA067': 'C_CAA067',
#  'C_CAA069': 'C_CAA069',
#  'C_CAA071': 'C_CAA071',
#  'C_CAA087': 'Dos Amigos Pumping Plant',
#  'C_CAA087_CVP': 'Dos Amigos Pumping Plant (CVP)',
#  'C_CAA087_SWP': 'Dos Amigos Pumping Plant (SWP)',
#  'C_CAA095': 'C_CAA095',
#  'C_CAA109': 'C_CAA109',
#  'C_CAA143': 'C_CAA143',
#  'C_CAA155': 'C_CAA155',
#  'C_CAA156': 'C_CAA156',
#  'C_CAA165': 'C_CAA165',
#  'C_CAA172': 'C_CAA172',
#  'C_CAA173': 'C_CAA173',
#  'C_CAA181': 'C_CAA181',
#  'C_CAA183': 'C_CAA183',
#  'C_CAA184': 'C_CAA184',
#  'C_CAA185': 'C_CAA185',
#  'C_CAA194': 'C_CAA194',
#  'C_CAA207': 'C_CAA207',
#  'C_CAA210': 'C_CAA210',
#  'C_CAA220': 'C_CAA220',
#  'C_CAA238': 'C_CAA238',
#  'C_CAA239': 'C_CAA239',
#  'C_CAA240': 'C_CAA240',
#  'C_CAA241': 'C_CAA241',
#  'C_CAA242': 'C_CAA242',
#  'C_CAA245': 'Buena Vista Pumping Plant',
#  'C_CAA262': 'C_CAA262',
#  'C_CAA278': 'Wheeler Ridge Pumping Plant',
#  'C_CAA279': 'C_CAA279',
#  'C_CAA280': 'Chrisman Pumping Plant',
#  'C_CAA293': 'Edmondston Pumping Plant',
#  'C_CAA305': 'C_CAA305',
#  'C_CLR011': 'Upstream Flows - Release-ClearCreek',
#  'C_CLV004': 'Calaveras River',
#  'C_CSL004B': 'Delta - North Bay Aqueduct',
#  'C_DMC000': None,
#  'C_DMC000_CVP': None,
#  'C_DMC000_EXP1': 'Other - Jones Export Fed Share',
#  'C_DMC000_EXP2': 'Other - Jones Export State Share',
#  'C_DMC000_IF': 'Other - Jones PP North Delta',
#  'C_DMC000_TD': 'Other - Jones PP Through Delta',
#  'C_DMC000_WTS': 'Other - Jones Export WTS',
#  'C_DMC116': 'Other - DMC inflow to MendotaPool',
#  'C_ESB361': 'Pearblossom PP & Reach 17-21 Losses',
#  'C_ESB406': 'Mojave PWP & Reach 22A-23 Losses   ',
#  'C_FTR003': 'Upstream Flows - FeatherMouth',
#  'C_FTR031': 'Upstream Flows - FeatherYubaConfluence',
#  'C_FTR059': 'Upstream Flows - Feather below Thermolito',
#  'C_FTR068': 'Upstream Flows - FeatherLowFlow',
#  'C_KSWCK': 'Upstream Flows - Release-Sacramento Keswick',
#  'C_LWSTN': 'Upstream Flows - Release-Trinity',
#  'C_MCD021': 'Upstream Flows - MercedMouth',
#  'C_MCLRE': 'Upstream Flows - Release-NewDonPedro',
#  'C_MDOTA': 'Upstream Flows - Release-MendotaPool',
#  'C_MELON': 'Upstream Flows - Release-NewMelones',
#  'C_MLRTN': 'Upstream Flows - Release-Friant',
#  'C_MOK019': 'Mokelumne River',
#  'C_MOK022': 'Upstream Flows - Mokelumne Flow',
#  'C_NTOMA': 'Upstream Flows - Release-American Nimbus',
#  'C_OMR014': 'Delta - Old and Middle River flow',
#  'C_OROVL': 'Upstream Flows - Release-Oroville',
#  'C_PEDRO': 'Upstream Flows - Release-McClure',
#  'C_SAC000': 'Total Delta Outflow',
#  'C_SAC017': 'Delta - Flow at Rio Vista',
#  'C_SAC029B': 'Delta - Flow at Georgiana Slough',
#  'C_SAC030': 'Delta - Flow below DXC',
#  'C_SAC041': 'Upstream Flows - SacFlowHood',
#  'C_SAC048': 'Delta - Sac Flow at Freeport',
#  'C_SAC083': 'Upstream Flows - SacFlowVerona',
#  'C_SAC085': 'Upstream Flows - SacFlowAbvFremontWeir',
#  'C_SAC097': 'Upstream Flows - SacFlowWilkinsSlough',
#  'C_SAC240': 'Upstream Flows - SacFlowRedBluff',
#  'C_SJR013': 'Upstream Flows - SJR QWEST flows',
#  'C_SJR070': 'Upstream Flows - Vernalis Flow',
#  'C_SJR075': 'Upstream Flows - SJRUpstreamStan',
#  'C_SJR119': 'Upstream Flows - SJRUpstreamMerc',
#  'C_STS030': 'Upstream Flows - StanislausMouth',
#  'C_STS059': 'Upstream Flows - Release-Stanislaus (Goodwin)',
#  'C_TUO003': 'Upstream Flows - TuolumneMouth',
#  'C_WKYTN': None,
#  'C_YBP020': 'Upstream Flows - Yolo Bypass',
#  'C_YUB002': 'Upstream Flows - YubaFeatherConfluence',
#  'C_YUB006': None,
#  'D408': 'Delta - CCWD',
#  'DELTAINFLOWFORNDOI': 'Delta - Delta Inflow (NDOI)',
#  'DELTARDV_TOTAL': 'Delivery - SWP Del Target TA + CO',
#  'DELTAR_A_DV': 'Delivery - SWP Del Target TA',
#  'DEL_CVP_PAG_N': 'Delivery - CVP Delivery PAG N',
#  'DEL_CVP_PAG_S': 'Delivery - CVP Delivery PAG S',
#  'DEL_CVP_PEX_S': 'Delivery - CVP Delivery PEX S',
#  'DEL_CVP_PMI_S': 'Delivery - CVP Delivery PMI S',
#  'DEL_CVP_PRF_N': 'Delivery - CVP Delivery PRF N',
#  'DEL_CVP_PRF_S': 'Delivery - CVP Delivery PRF S',
#  'DEL_CVP_PSC_N': 'Delivery - CVP Delivery PSC N',
#  'DEL_CVP_TOTAL_N': 'Delivery - CVP Delivery NOD',
#  'DEL_CVP_TOTAL_S': 'Delivery - CVP Delivery SOD no CVC',
#  'DEL_SWP_PIN': 'Other - SWP Delivery Int',
#  'DXC': 'Other - DCC gate days open',
#  'D_BKR004_NBA009_NAPA_PRJ': 'Napa via North Bay Aqueduct',
#  'D_BKR004_NBA009_SCWA_PRJ': 'Solano via North Bay Aqueduct',
#  'D_LWSTN_ADD': 'Other - Trinity Export Excess',
#  'D_LWSTN_CCT011': 'Other - Trinity Export',
#  'D_LWSTN_IMPORT': 'Other - Trinity Export Ops x',
#  'D_OMR027_CAA000': 'Delta - Banks Exports',
#  'D_OMR028_DMC000': 'Delta - Jones Exports',
#  'D_SAC030_MOK014': 'Delta - DXC Flow',
#  'D_SAC207_GCC007': 'Other - Hamilton City (diversion)',
#  'D_SAC240_TCC001': 'Other - Red Bluff Diversion Dam (diversion)',
#  'D_WKYTN_SPT003': 'Upstream Flows - Spring Creek Tunnel',
#  'EM_EC_MONTH': 'Salinity - EM EC',
#  'EXPORTACTUALIF': 'Delta - Total NDD Exports',
#  'EXPORTACTUALTD': 'Delta - Total TD Exports',
#  'EXPRATIO_': 'Other - EI RATIO',
#  'GP_SACWBA': None,
#  'JP_EC_MONTH': 'Salinity - JP EC',
#  'LV_EC_MONTH': 'Salinity - LV EC',
#  'MAXEXP_RPA_CVPDV': 'Other - RPA Constraint Jones',
#  'MAXEXP_RPA_SWPDV': 'Other - RPA Constraint Banks',
#  'MRDO_FINALDV': 'Delta - Modeled Required DO',
#  'MR_EC_MONTH': 'Salinity - MR EC',
#  'NDOI': 'Delta - Delta Outflow (NDOI)',
#  'NDOI_ADD': 'Delta - Excess Outflow (NDOI)',
#  'NDOI_ADD_ANN': 'Delta - Excess Outflow ANN (NDOI)',
#  'NDOI_ADD_CVP': 'Delta - Excess Outflow CVP (NDOI)',
#  'NDOI_ADD_SWP': 'Delta - Excess Outflow SWP (NDOI)',
#  'NDOI_MIN': 'Delta - Required Delta Outflow',
#  'NET_DICU': 'Other - net DICU',
#  'PERDV_CVPAG_S': 'Delivery - CVP Allocation (SOD Ag)',
#  'PERDV_CVPAG_SYS': 'Delivery - CVP Allocation (NOD Ag)',
#  'PERDV_CVPEX_S': 'Delivery - CVP Allocation (SOD EX)',
#  'PERDV_CVPMI_S': 'Delivery - CVP Allocation (SOD M&I)',
#  'PERDV_CVPMI_SYS': 'Delivery - CVP Allocation (NOD M&I)',
#  'PERDV_CVPRF_S': 'Delivery - CVP Allocation (SOD RF)',
#  'PERDV_CVPRF_SYS': 'Delivery - CVP Allocation (NOD RF)',
#  'PERDV_CVPSC_SYS': 'Delivery - CVP Allocation (NOD SC)',
#  'PERDV_SWP_FSC': 'Other - SWP Allocation (FRSA)',
#  'PERDV_SWP_MWD1': 'Other - SWP Allocation (M&I)',
#  'RS_EC_MONTH': 'Salinity - RS EC',
#  'SHORT_CVP_TOT_N': 'Delivery - SHORT_CVP_TOT_N',
#  'SHORT_CVP_TOT_S': 'Delivery - SHORT_CVP_TOT_S',
#  'SHORT_SWP_TOTA': 'Other - SHORT_SWP_TOTAL',
#  'SP_SAC066_YBP020': 'Upstream Flows - Sacramento Weir spills',
#  'SP_SAC083_YBP037': 'Upstream Flows - Fremont Weir spills',
#  'SWPRuleCv': 'Storage - SL SWP Rule curve',
#  'SWP_CO_FEATH': 'Delivery - SWP_CO_FEATH',
#  'SWP_CO_NBAY': 'Delivery - SWP_CO_NBAY',
#  'SWP_CO_TOTAL': 'Delivery - SWP_CO_TOTAL',
#  'SWP_IN_FEATH': 'Delivery - SWP_IN_FEATH',
#  'SWP_IN_NBAY': 'Delivery - SWP_IN_NBAY',
#  'SWP_IN_TOTAL': 'Delivery - SWP_IN_TOTAL',
#  'SWP_LOSS': 'Delivery - SWP_LOSS',
#  'SWP_PERDELDV': 'Delivery - SWP PERCENT DELIVERY',
#  'SWP_TA_FEATH': 'Delivery - SWP_TA_FEATH',
#  'SWP_TA_NBAY': 'Delivery - SWP_TA_NBAY',
#  'SWP_TA_TOTAL': 'Delivery - SWP_TA_TOTAL',
#  'S_FOLSM': 'Storage - Folsom Storage',
#  'S_MCLRE': 'Storage - McClure Storage',
#  'S_MELON': 'Storage - New Melones Storage',
#  'S_MLRTN': 'Storage - Friant Storage',
#  'S_OROVL': 'Storage - Oroville Storage',
#  'S_PEDRO': 'Storage - New Don Pedro Storage',
#  'S_SHSTA': 'Storage - Shasta Storage',
#  'S_SLUIS_CVP': 'Storage - San Luis Storage - CVP',
#  'S_SLUIS_SWP': 'Storage - San Luis Storage - SWP',
#  'S_TRNTY': 'Storage - Trinity Storage',
#  'S_WKYTN': 'Storage - Whiskeytown',
#  'UNUSED_TOTALDV': 'Delivery - SWP_UNUSED_TA_TOTAL',
#  'VARDELTARDV': 'Delivery - SWP Var Demand Deltar',
#  'VI_EC_MONTH': 'Salinity - VI EC',
#  'WYT_SAC_': 'WYT_SAC_',
#  'X2_PRV': 'Salinity - X2 Position prev',
#  'C_ESB306': 'SWP Alamo Powerplant               ',
#  'C_ESB324': 'SWP Reach 19-22A  Avek Wa          ',
#  'C_ESB347': 'SWP Reach 20A-20B  Palmdale WD     ',
#  'C_ESB355': 'SWP Reach 21  Littlerock Cr Id     ',
#  'C_ESB403': 'SWP Reach 22B-23  Mojave Wa        ',
#  'C_ESB407': 'SWP Reach 26A Coachella Valley WD  ',
#  'C_ESB408': 'SWP Reach 26A  Desert Wa           ',
#  'C_ESB413': 'SWP Reach 26  MWD                  ',
#  'C_ESB414': 'SWP Reach 26A  San Bernardino      ',
#  'C_ESB415': 'SWP Reach 26  San Gabriel Valley   ',
#  'C_ESB420': 'SWP Reach 26 San Gorgonio Pass Wa  ',
#  'C_ESB425': 'SWP Reach 24-28  Rec + Losses      ',
#  'C_ESB433': 'SWP Reach 28G-28H  MWD              ',
#  'C_WSB001': 'SWP OSO Power Plant                ',
#  'C_WSB006': 'SWP Reach 29A-29F Losses           ',
#  'C_WSB014': 'SWP Warne PWP & Reach 29A-F Losses ',
#  'C_WSB026': ' Castaic PWP & Reach 29H-29J Losses',
#  'C_WSB027': ' SWP Reach 30  Rec + Losses        ',
#  'C_WSB031': ' SWP Reach 30  MWD                 '}
